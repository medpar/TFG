# %%
import os
import sys
sys.path.append(os.path.dirname(os.getcwd())) #Add project dir to path
from utils.plotUtilities import plotVideoPoseAllSubjectsOneActivity_mmpose

# %% [markdown]
# ## Generates _.svg_ and _.pdf_ plots the joint angles estimated from 3D joint positions in _.csv_ files.

# %% [markdown]
# Set dataset root

# %%
fulldatasetpath = '/mnt/b/VIDIMU'
print("Ruta al dataset: ", fulldatasetpath)
# Out:
# Ruta al dataset:  /mnt/b/VIDIMU

# %% [markdown]
# Select activities

# %%
lower_activities = ["A01"]
dataset_activities = lower_activities
activities_legend = ["walk_forward"]

# %% [markdown]
# ### 1. From 'dataset/videonly' to 'analysis/videonly/vangles'

# %%
subjects = ["S01", "S02"]

# %%
inpath = os.path.join(fulldatasetpath, 'extra', 'dataset','videonly')
outpath = os.path.join(fulldatasetpath,'extra', 'analysis','videonly','vangles')
if not os.path.exists(outpath):
    os.makedirs(outpath)
for activity,legend in zip(dataset_activities,activities_legend):
    print("Activity "+activity)
    plotVideoPoseAllSubjectsOneActivity_mmpose(inpath,outpath,subjects,activity,legend,"VideoJointAngles_"+activity+"_"+legend)
# Out:
# Activity A01
# None
# None

# %% [markdown]
# ### 2. From 'dataset/videandimus' to 'analysis/videoandimus/vangles'

# %%
subjects = ["S40","S41"]

# %%
inpath = os.path.join(fulldatasetpath,'extra', 'dataset','videoandimus')
outpath = os.path.join(fulldatasetpath,'extra', 'analysis','videoandimus','vangles')
if not os.path.exists(outpath):
    os.makedirs(outpath)
for activity,legend in zip(dataset_activities,activities_legend):
    print("Activity "+activity)
    plotVideoPoseAllSubjectsOneActivity_mmpose(inpath,outpath,subjects,activity,legend,"VideoJointAngles_"+activity+"_"+legend)
# Out:
# Activity A01
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 7
#       5 for activity,legend in zip(dataset_activities,activities_legend):
#       6     print("Activity "+activity)
# ----> 7     plotVideoPoseAllSubjectsOneActivity_mmpose(inpath,outpath,subjects,activity,legend,"VideoJointAngles_"+activity+"_"+legend)
#
# File ~/vidimu-tools/extra/utils/plotUtilities.py:39, in plotVideoPoseAllSubjectsOneActivity_mmpose(inpath, outpath, subjects, activity, activity_legend, outputfilename)
#      36     print("None")
#      37     continue
# ---> 39 arm_flex_r,arm_flex_l,elbow_flex_r,elbow_flex_l,knee_angle_r,knee_angle_l=fp.getMainJointAnglesFromCSV2_mmpose(dfcsv)
#      40 arm_flex_r_filt = sp.applyMedianFilter(arm_flex_r,11)
#      41 arm_flex_l_filt = sp.applyMedianFilter(arm_flex_l,11)
#
# File ~/vidimu-tools/extra/utils/fileProcessing.py:60, in getMainJointAnglesFromCSV2_mmpose(dfcsv)
#      58 def getMainJointAnglesFromCSV2_mmpose(dfcsv):
#      59     # Map CSV columns to variables
# ---> 60     torso = dfcsv[['spine_x', 'spine_y', 'spine_z']].to_numpy()
#      61     neck = dfcsv[['neck_base_x', 'neck_base_y', 'neck_base_z']].to_numpy()
#      62     rshoulder = dfcsv[['right_shoulder_x', 'right_shoulder_y', 'right_shoulder_z']].to_numpy()
#
# File ~/miniconda3/envs/vidimu/lib/python3.9/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/miniconda3/envs/vidimu/lib/python3.9/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/miniconda3/envs/vidimu/lib/python3.9/site-packages/pandas/core/indexes/base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['spine_x', 'spine_y', 'spine_z'], dtype='object')] are in the [columns]"
